# %%
import randomwalk
from matplotlib import pyplot as plt
import numpy as np

dx = np.array([[0]])
F = np.array([[.9]])
dv = np.array([[.1]])
G = np.array([[.99]])


A,B = randomwalk.mom_random_walk(10000,F,G,dx,dv)

A.shape
# Out:
# (10001,)

# %%
plt.plot(A)
plt.show()

# %%
plt.hist(A)
plt.show()

# %%
from scipy.stats import kurtosis

kurtosis(A)
# Out:
# 0.09439571340796427
